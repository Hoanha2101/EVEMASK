# %% [markdown]
# ## Number of label photos per person:

# %%
import os

"""
Script: count_json_files_by_labeler.py

Purpose:
    - Count how many LabelMe JSON files are associated with each annotator,
      inferred from annotator identifiers embedded in the filenames.

Inputs:
    - folder_path: Directory containing JSON files.
    - labelers:    List of annotator identifiers to match in filenames.

Outputs:
    - Console summary of counts per annotator.
    - Console total of matched JSON files.

Notes:
    - A file is counted for at most one annotator (first match wins).
"""

# === CONFIGURATION ===
folder_path = "data_json"  # Directory containing the JSON files

# List of annotator identifiers to count
labelers = ["Chaudpb", "Thunv10", "NghiaNT20", "khaihoan2003"]

# === INITIALIZE COUNTERS ===
counts = {labeler: 0 for labeler in labelers}

# === ITERATE OVER FILES AND COUNT MATCHES ===
for filename in os.listdir(folder_path):
    if filename.endswith(".json"):
        for labeler in labelers:
            if labeler in filename:
                counts[labeler] += 1
                # Stop after the first match to avoid double counting
                break

# === PRINT PER-LABELER SUMMARY ===
for labeler, count in counts.items():
    print(f"{labeler}: {count} JSON file(s)")

# === PRINT TOTAL MATCHED FILES ===
total_files = sum(counts.values())
print(f"Total matched JSON files: {total_files}")
# Out:
# Chaudpb: 557 JSON file(s)
# Thunv10: 615 JSON file(s)
# NghiaNT20: 364 JSON file(s)
# khaihoan2003: 505 JSON file(s)
# Total matched JSON files: 2041

# %% [markdown]
# ## Reformat label name:

# %%
# This cell normalizes all "label" fields in LabelMe JSON files to lowercase.
import os
import json

"""
Script: normalize_labels_to_lowercase.py

Purpose:
    - Iterate over LabelMe JSON files and convert every "label" value to lowercase in-place.

Inputs:
    - folder_path: Directory containing LabelMe JSON files.

Outputs:
    - Overwrites modified JSON files on disk.
    - Console messages indicating which files were updated and a completion notice.

Notes:
    - Only writes back files that actually changed (at least one label was not already lowercase).
"""

# === CONFIGURATION ===
folder_path = "data_json"  # Directory containing LabelMe JSON files

# === ITERATE OVER JSON FILES IN THE DIRECTORY ===
for filename in os.listdir(folder_path):
    if filename.endswith(".json"):
        file_path = os.path.join(folder_path, filename)
        try:
            with open(file_path, "r", encoding="utf-8") as f:
                data = json.load(f)

            modified = False

            # Normalize each shape's label to lowercase
            for shape in data.get("shapes", []):
                label = shape.get("label")
                if label and label != label.lower():
                    shape["label"] = label.lower()
                    modified = True

            # Write back only if any label changed
            if modified:
                with open(file_path, "w", encoding="utf-8") as f:
                    json.dump(data, f, ensure_ascii=False, indent=2)

                print(f"Normalized labels in: {filename}")

        except Exception as e:
            print(f"Error processing {filename}: {e}")

print("Completed normalizing all labels to lowercase.")
# Out:
# Completed normalizing all labels to lowercase.

# %% [markdown]
# ## Recheck number of label.

# %%
import os
import json
from collections import Counter

"""
Script: count_labels_from_labelme_json.py

Purpose:
    - Iterate through LabelMe JSON files and count how many times each label appears.

Inputs:
    - folder_path: Directory containing LabelMe JSON files (non-recursive).

Outputs:
    - Console summary listing each label and its count, sorted by descending frequency.

Notes:
    - Only keys under data["shapes"][*]["label"] are counted.
"""

# === CONFIGURATION ===
folder_path = "data_json"  # Directory containing LabelMe JSON files

# === STATE ===
label_counter = Counter()

# === ITERATE OVER JSON FILES IN THE FOLDER ===
for filename in os.listdir(folder_path):
    if filename.endswith(".json"):
        json_path = os.path.join(folder_path, filename)
        try:
            with open(json_path, "r", encoding="utf-8") as f:
                data = json.load(f)

            for shape in data.get("shapes", []):
                label = shape.get("label")
                if label:
                    label_counter[label] += 1

        except Exception as e:
            print(f"Error reading {filename}: {e}")

# === PRINT SUMMARY ===
print("Label frequency summary:")
for label, count in label_counter.most_common():
    print(f"- {label}: {count}")
# Out:
# Label frequency summary:
# - unbet: 16818
# - fanduel: 1435
# - betway: 437
# - draftkings: 260
# - bally: 240
# - bet365: 159
# - gilariver: 152
# - betrivers: 65
# - pointsbet: 60
# - betmgm: 50
# - caesars: 38
# - fanatics: 31
# - betparx: 7
# - casino: 4

# %% [markdown]
# ## Conver Json label file to txt format (YOLO segment format):

# %%
"""
Script: labelme_to_yolov8_seg.py

Purpose:
    - Convert LabelMe JSON annotations to YOLOv8 Segmentation label files (.txt).
    - For each polygon, write one line per instance:
        class_id x_center y_center width height p1x p1y p2x p2y ... (all normalized)
    - One output .txt per input JSON (same stem name).

Inputs:
    - input_folder:  Directory of LabelMe JSON files.
    - output_folder: Destination directory for YOLOv8 .txt labels.
    - label_names:   Mapping from label string (lowercased) to class_id.

Outputs:
    - For each JSON "imageName.json" -> "imageName.txt" written to output_folder.

Notes:
    - Only polygon shapes with >= 3 points are converted.
    - Labels not found in label_names are skipped (reported at the end).
    - If a JSON contains no valid polygons, an empty .txt is still created.
"""

# === CONFIGURATION ===
input_folder = "data_json"
output_folder = "data_txt"

os.makedirs(output_folder, exist_ok=True)

# === CLASS-ID MAPPING (lowercase labels) ===
label_names = {
    "unbet": 0, "betrivers": 1, "fanduel": 2,
    "betway": 3, "caesars": 4, "bally": 5,
    "draftkings": 6, "pointsbet": 7, "bet365": 8,
    "fanatics": 9, "betparx": 10, "betmgm": 11,
    "gilariver": 12, "casino": 13
}

# === HELPERS ===
def normalize(value: float, max_value: float) -> float:
    """Normalize a pixel coordinate to [0, 1] with rounding."""
    if max_value <= 0:
        return 0.0
    x = value / max_value
    # optional clamp for numerical safety
    if x < 0:
        x = 0.0
    elif x > 1:
        x = 1.0
    return round(x, 6)


# === CONVERT ALL JSON FILES ===
unknown_labels = set()
files_processed = 0

for file in os.listdir(input_folder):
    if not file.endswith(".json"):
        continue

    json_path = os.path.join(input_folder, file)
    try:
        with open(json_path, "r", encoding="utf-8") as f:
            data = json.load(f)

        image_w = data.get("imageWidth")
        image_h = data.get("imageHeight")
        if not image_w or not image_h:
            print(f"[WARN] Missing imageWidth/Height in: {file} — skipped.")
            continue

        lines = []
        shapes = data.get("shapes", [])

        for shape in shapes:
            label = (shape.get("label") or "").strip().lower()
            if not label:
                continue

            if label not in label_names:
                unknown_labels.add(label)
                # Skip shapes whose label is not in the mapping
                continue

            points = shape.get("points") or []
            if len(points) < 3:
                # YOLOv8 Seg requires polygons with at least 3 points
                continue

            # Bounding box in pixels
            x_coords = [pt[0] for pt in points]
            y_coords = [pt[1] for pt in points]
            x_min, x_max = min(x_coords), max(x_coords)
            y_min, y_max = min(y_coords), max(y_coords)

            # Convert bbox to normalized center-width-height
            x_center = normalize((x_min + x_max) / 2, image_w)
            y_center = normalize((y_min + y_max) / 2, image_h)
            bbox_w   = normalize(x_max - x_min, image_w)
            bbox_h   = normalize(y_max - y_min, image_h)

            # Polygon points (normalized, flattened as x1 y1 x2 y2 ...)
            poly_points = []
            for x, y in points:
                poly_points.append(normalize(x, image_w))
                poly_points.append(normalize(y, image_h))

            class_id = label_names[label]

            # YOLOv8-Seg line format
            values = [str(class_id), str(x_center), str(y_center), str(bbox_w), str(bbox_h)]
            values.extend(str(p) for p in poly_points)
            line = " ".join(values)
            lines.append(line)

        # Write output .txt (create empty if no valid polygons)
        output_name = os.path.splitext(file)[0] + ".txt"
        output_path = os.path.join(output_folder, output_name)
        with open(output_path, "w", encoding="utf-8") as f:
            f.write("\n".join(lines))

        files_processed += 1
        print(f"[OK] Processed: {file} -> {output_name} ({len(lines)} instance(s))")

    except Exception as e:
        print(f"[ERROR] {file}: {e}")

print(f"Conversion finished. Files processed: {files_processed}")
if unknown_labels:
    print(f"Unknown labels encountered (skipped): {sorted(unknown_labels)}")
# Out:
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000001.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000001.txt (20 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000002.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000002.txt (14 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000003.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000003.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000004.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000004.txt (11 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000006.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000006.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000007.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000007.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000008.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000008.txt (9 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000009.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000009.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000010.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000010.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000011.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000011.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000012.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000012.txt (11 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000013.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000013.txt (11 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000014.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000014.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000015.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000015.txt (4 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000016.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000016.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000017.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000017.txt (5 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000018.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000018.txt (5 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000019.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000019.txt (9 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000020.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000020.txt (9 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000021.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000021.txt (7 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000022.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000022.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000023.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000023.txt (14 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000025.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000025.txt (1 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000029.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000029.txt (11 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000030.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000030.txt (9 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000031.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000031.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000033.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000033.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000034.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000034.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000035.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000035.txt (11 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000036.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000036.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000037.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000037.txt (7 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000038.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000038.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000039.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000039.txt (9 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000041.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000041.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000042.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000042.txt (9 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000043.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000043.txt (11 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000044.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000044.txt (11 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000045.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000045.txt (14 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000046.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000046.txt (1 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000048.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000048.txt (9 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000050.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000050.txt (7 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000056.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000056.txt (12 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000057.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000057.txt (11 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000058.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000058.txt (12 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000059.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000059.txt (7 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000060.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000060.txt (11 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000061.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000061.txt (11 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000062.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000062.txt (11 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000064.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000064.txt (11 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000066.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000066.txt (12 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000067.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000067.txt (11 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000068.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000068.txt (7 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000069.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000069.txt (12 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000070.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000070.txt (4 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000071.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000071.txt (4 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000072.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000072.txt (7 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000073.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000073.txt (1 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000074.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000074.txt (6 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000075.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000075.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000076.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000076.txt (7 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000077.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000077.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000078.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000078.txt (7 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000080.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000080.txt (8 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000081.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000081.txt (12 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000082.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000082.txt (7 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000083.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000083.txt (8 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000084.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000084.txt (12 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000085.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000085.txt (11 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000086.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000086.txt (11 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000087.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000087.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000088.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000088.txt (13 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000091.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000091.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000093.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000093.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000094.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000094.txt (7 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000095.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000095.txt (9 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000096.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000096.txt (8 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000098.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000098.txt (1 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000101.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000101.txt (7 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000102.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000102.txt (11 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000103.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000103.txt (13 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000106.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000106.txt (4 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000107.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000107.txt (8 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000109.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000109.txt (12 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000110.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000110.txt (13 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000111.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000111.txt (8 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000112.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000112.txt (14 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000113.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000113.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000114.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000114.txt (6 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000117.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000117.txt (20 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000118.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000118.txt (12 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000119.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000119.txt (9 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000120.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000120.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000121.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000121.txt (6 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000122.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000122.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000123.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000123.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000125.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000125.txt (10 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000129.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000129.txt (11 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000130.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000130.txt (11 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000131.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000131.txt (12 instance(s))
# [OK] Processed: BostonCeltics_NewYorkKnicks_1205_Chaudpb_000134.json -> BostonCeltics_NewYorkKnicks_1205_Chaudpb_000134.txt (11 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001131.json -> BucksJazz_1305_Thunv10_001131.txt (10 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001132.json -> BucksJazz_1305_Thunv10_001132.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001133.json -> BucksJazz_1305_Thunv10_001133.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001134.json -> BucksJazz_1305_Thunv10_001134.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001135.json -> BucksJazz_1305_Thunv10_001135.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001136.json -> BucksJazz_1305_Thunv10_001136.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001138.json -> BucksJazz_1305_Thunv10_001138.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001141.json -> BucksJazz_1305_Thunv10_001141.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001142.json -> BucksJazz_1305_Thunv10_001142.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001143.json -> BucksJazz_1305_Thunv10_001143.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001242.json -> BucksJazz_1305_Thunv10_001242.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001243.json -> BucksJazz_1305_Thunv10_001243.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001258.json -> BucksJazz_1305_Thunv10_001258.txt (8 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001259.json -> BucksJazz_1305_Thunv10_001259.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001260.json -> BucksJazz_1305_Thunv10_001260.txt (8 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001262.json -> BucksJazz_1305_Thunv10_001262.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001263.json -> BucksJazz_1305_Thunv10_001263.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001265.json -> BucksJazz_1305_Thunv10_001265.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001266.json -> BucksJazz_1305_Thunv10_001266.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001267.json -> BucksJazz_1305_Thunv10_001267.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001320.json -> BucksJazz_1305_Thunv10_001320.txt (10 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001321.json -> BucksJazz_1305_Thunv10_001321.txt (10 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_001322.json -> BucksJazz_1305_Thunv10_001322.txt (10 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_005527.json -> BucksJazz_1305_Thunv10_005527.txt (10 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_005528.json -> BucksJazz_1305_Thunv10_005528.txt (10 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_005529.json -> BucksJazz_1305_Thunv10_005529.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_005530.json -> BucksJazz_1305_Thunv10_005530.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_005531.json -> BucksJazz_1305_Thunv10_005531.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_005532.json -> BucksJazz_1305_Thunv10_005532.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_005534.json -> BucksJazz_1305_Thunv10_005534.txt (9 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_005560.json -> BucksJazz_1305_Thunv10_005560.txt (8 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_005561.json -> BucksJazz_1305_Thunv10_005561.txt (6 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_005562.json -> BucksJazz_1305_Thunv10_005562.txt (6 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_005563.json -> BucksJazz_1305_Thunv10_005563.txt (7 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_005564.json -> BucksJazz_1305_Thunv10_005564.txt (7 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_005565.json -> BucksJazz_1305_Thunv10_005565.txt (7 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_005566.json -> BucksJazz_1305_Thunv10_005566.txt (8 instance(s))
# [OK] Processed: BucksJazz_1305_Thunv10_005567.json -> BucksJazz_1305_Thunv10_005567.txt (9 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000001.json -> Cavaliers_vs_Nets_1305_Thunv10_000001.txt (11 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000003.json -> Cavaliers_vs_Nets_1305_Thunv10_000003.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000004.json -> Cavaliers_vs_Nets_1305_Thunv10_000004.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000006.json -> Cavaliers_vs_Nets_1305_Thunv10_000006.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000009.json -> Cavaliers_vs_Nets_1305_Thunv10_000009.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000010.json -> Cavaliers_vs_Nets_1305_Thunv10_000010.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000012.json -> Cavaliers_vs_Nets_1305_Thunv10_000012.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000013.json -> Cavaliers_vs_Nets_1305_Thunv10_000013.txt (2 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000014.json -> Cavaliers_vs_Nets_1305_Thunv10_000014.txt (2 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000016.json -> Cavaliers_vs_Nets_1305_Thunv10_000016.txt (1 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000017.json -> Cavaliers_vs_Nets_1305_Thunv10_000017.txt (14 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000018.json -> Cavaliers_vs_Nets_1305_Thunv10_000018.txt (1 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000021.json -> Cavaliers_vs_Nets_1305_Thunv10_000021.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000022.json -> Cavaliers_vs_Nets_1305_Thunv10_000022.txt (12 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000026.json -> Cavaliers_vs_Nets_1305_Thunv10_000026.txt (2 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000029.json -> Cavaliers_vs_Nets_1305_Thunv10_000029.txt (2 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000030.json -> Cavaliers_vs_Nets_1305_Thunv10_000030.txt (2 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000031.json -> Cavaliers_vs_Nets_1305_Thunv10_000031.txt (2 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000032.json -> Cavaliers_vs_Nets_1305_Thunv10_000032.txt (2 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000033.json -> Cavaliers_vs_Nets_1305_Thunv10_000033.txt (3 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000034.json -> Cavaliers_vs_Nets_1305_Thunv10_000034.txt (12 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000036.json -> Cavaliers_vs_Nets_1305_Thunv10_000036.txt (12 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000038.json -> Cavaliers_vs_Nets_1305_Thunv10_000038.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000039.json -> Cavaliers_vs_Nets_1305_Thunv10_000039.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000040.json -> Cavaliers_vs_Nets_1305_Thunv10_000040.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000041.json -> Cavaliers_vs_Nets_1305_Thunv10_000041.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000043.json -> Cavaliers_vs_Nets_1305_Thunv10_000043.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000044.json -> Cavaliers_vs_Nets_1305_Thunv10_000044.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000047.json -> Cavaliers_vs_Nets_1305_Thunv10_000047.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000048.json -> Cavaliers_vs_Nets_1305_Thunv10_000048.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000049.json -> Cavaliers_vs_Nets_1305_Thunv10_000049.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000050.json -> Cavaliers_vs_Nets_1305_Thunv10_000050.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000051.json -> Cavaliers_vs_Nets_1305_Thunv10_000051.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000054.json -> Cavaliers_vs_Nets_1305_Thunv10_000054.txt (15 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000055.json -> Cavaliers_vs_Nets_1305_Thunv10_000055.txt (15 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000057.json -> Cavaliers_vs_Nets_1305_Thunv10_000057.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000058.json -> Cavaliers_vs_Nets_1305_Thunv10_000058.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000059.json -> Cavaliers_vs_Nets_1305_Thunv10_000059.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000060.json -> Cavaliers_vs_Nets_1305_Thunv10_000060.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000062.json -> Cavaliers_vs_Nets_1305_Thunv10_000062.txt (12 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000064.json -> Cavaliers_vs_Nets_1305_Thunv10_000064.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000065.json -> Cavaliers_vs_Nets_1305_Thunv10_000065.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000066.json -> Cavaliers_vs_Nets_1305_Thunv10_000066.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000068.json -> Cavaliers_vs_Nets_1305_Thunv10_000068.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000069.json -> Cavaliers_vs_Nets_1305_Thunv10_000069.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000070.json -> Cavaliers_vs_Nets_1305_Thunv10_000070.txt (14 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000071.json -> Cavaliers_vs_Nets_1305_Thunv10_000071.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000072.json -> Cavaliers_vs_Nets_1305_Thunv10_000072.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000073.json -> Cavaliers_vs_Nets_1305_Thunv10_000073.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000075.json -> Cavaliers_vs_Nets_1305_Thunv10_000075.txt (2 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000077.json -> Cavaliers_vs_Nets_1305_Thunv10_000077.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000078.json -> Cavaliers_vs_Nets_1305_Thunv10_000078.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000079.json -> Cavaliers_vs_Nets_1305_Thunv10_000079.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000082.json -> Cavaliers_vs_Nets_1305_Thunv10_000082.txt (9 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000083.json -> Cavaliers_vs_Nets_1305_Thunv10_000083.txt (9 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000084.json -> Cavaliers_vs_Nets_1305_Thunv10_000084.txt (4 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000085.json -> Cavaliers_vs_Nets_1305_Thunv10_000085.txt (12 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000086.json -> Cavaliers_vs_Nets_1305_Thunv10_000086.txt (5 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000087.json -> Cavaliers_vs_Nets_1305_Thunv10_000087.txt (5 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000088.json -> Cavaliers_vs_Nets_1305_Thunv10_000088.txt (5 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000089.json -> Cavaliers_vs_Nets_1305_Thunv10_000089.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000090.json -> Cavaliers_vs_Nets_1305_Thunv10_000090.txt (12 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000091.json -> Cavaliers_vs_Nets_1305_Thunv10_000091.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000092.json -> Cavaliers_vs_Nets_1305_Thunv10_000092.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000094.json -> Cavaliers_vs_Nets_1305_Thunv10_000094.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000095.json -> Cavaliers_vs_Nets_1305_Thunv10_000095.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000097.json -> Cavaliers_vs_Nets_1305_Thunv10_000097.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000098.json -> Cavaliers_vs_Nets_1305_Thunv10_000098.txt (13 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000099.json -> Cavaliers_vs_Nets_1305_Thunv10_000099.txt (12 instance(s))
# [OK] Processed: Cavaliers_vs_Nets_1305_Thunv10_000100.json -> Cavaliers_vs_Nets_1305_Thunv10_000100.txt (13 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000000.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000000.txt (11 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000001.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000001.txt (11 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000002.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000002.txt (11 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000017.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000017.txt (11 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000018.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000018.txt (8 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000019.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000019.txt (11 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000020.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000020.txt (11 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000021.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000021.txt (5 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000024.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000024.txt (5 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000025.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000025.txt (13 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000026.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000026.txt (12 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000027.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000027.txt (13 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000028.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000028.txt (11 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000029.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000029.txt (13 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000030.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000030.txt (12 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000031.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000031.txt (11 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000032.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000032.txt (11 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000033.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000033.txt (6 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000034.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000034.txt (5 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000035.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000035.txt (7 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000036.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000036.txt (9 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000037.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000037.txt (11 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000038.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000038.txt (12 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000039.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000039.txt (13 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000040.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000040.txt (13 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000041.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000041.txt (13 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000042.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000042.txt (11 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000043.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000043.txt (11 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000044.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000044.txt (11 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000045.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000045.txt (11 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000046.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000046.txt (11 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000047.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000047.txt (6 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000053.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000053.txt (6 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000054.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000054.txt (7 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000055.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000055.txt (12 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000056.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000056.txt (12 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000057.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000057.txt (13 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000058.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000058.txt (13 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000059.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000059.txt (13 instance(s))
# [OK] Processed: DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000060.json -> DenverNuggets_vs_TorontoRaptors_1105_Thunv10_000060.txt (13 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000001.json -> epicducks_posters_1205_NghiaNT20_000001.txt (3 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000002.json -> epicducks_posters_1205_NghiaNT20_000002.txt (13 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000003.json -> epicducks_posters_1205_NghiaNT20_000003.txt (14 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000004.json -> epicducks_posters_1205_NghiaNT20_000004.txt (4 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000005.json -> epicducks_posters_1205_NghiaNT20_000005.txt (6 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000006.json -> epicducks_posters_1205_NghiaNT20_000006.txt (14 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000007.json -> epicducks_posters_1205_NghiaNT20_000007.txt (15 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000008.json -> epicducks_posters_1205_NghiaNT20_000008.txt (14 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000009.json -> epicducks_posters_1205_NghiaNT20_000009.txt (7 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000011.json -> epicducks_posters_1205_NghiaNT20_000011.txt (1 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000012.json -> epicducks_posters_1205_NghiaNT20_000012.txt (3 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000013.json -> epicducks_posters_1205_NghiaNT20_000013.txt (3 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000014.json -> epicducks_posters_1205_NghiaNT20_000014.txt (12 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000015.json -> epicducks_posters_1205_NghiaNT20_000015.txt (14 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000016.json -> epicducks_posters_1205_NghiaNT20_000016.txt (14 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000019.json -> epicducks_posters_1205_NghiaNT20_000019.txt (1 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000028.json -> epicducks_posters_1205_NghiaNT20_000028.txt (9 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000029.json -> epicducks_posters_1205_NghiaNT20_000029.txt (11 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000031.json -> epicducks_posters_1205_NghiaNT20_000031.txt (8 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000033.json -> epicducks_posters_1205_NghiaNT20_000033.txt (5 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000034.json -> epicducks_posters_1205_NghiaNT20_000034.txt (7 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000035.json -> epicducks_posters_1205_NghiaNT20_000035.txt (2 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000036.json -> epicducks_posters_1205_NghiaNT20_000036.txt (3 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000037.json -> epicducks_posters_1205_NghiaNT20_000037.txt (3 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000048.json -> epicducks_posters_1205_NghiaNT20_000048.txt (9 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000049.json -> epicducks_posters_1205_NghiaNT20_000049.txt (9 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000051.json -> epicducks_posters_1205_NghiaNT20_000051.txt (6 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000054.json -> epicducks_posters_1205_NghiaNT20_000054.txt (15 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000056.json -> epicducks_posters_1205_NghiaNT20_000056.txt (3 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000057.json -> epicducks_posters_1205_NghiaNT20_000057.txt (4 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000059.json -> epicducks_posters_1205_NghiaNT20_000059.txt (12 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000063.json -> epicducks_posters_1205_NghiaNT20_000063.txt (12 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000077.json -> epicducks_posters_1205_NghiaNT20_000077.txt (18 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000078.json -> epicducks_posters_1205_NghiaNT20_000078.txt (15 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000079.json -> epicducks_posters_1205_NghiaNT20_000079.txt (15 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000081.json -> epicducks_posters_1205_NghiaNT20_000081.txt (15 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000083.json -> epicducks_posters_1205_NghiaNT20_000083.txt (17 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000085.json -> epicducks_posters_1205_NghiaNT20_000085.txt (14 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000086.json -> epicducks_posters_1205_NghiaNT20_000086.txt (19 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000090.json -> epicducks_posters_1205_NghiaNT20_000090.txt (1 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000091.json -> epicducks_posters_1205_NghiaNT20_000091.txt (2 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000092.json -> epicducks_posters_1205_NghiaNT20_000092.txt (1 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000093.json -> epicducks_posters_1205_NghiaNT20_000093.txt (2 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000095.json -> epicducks_posters_1205_NghiaNT20_000095.txt (12 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000096.json -> epicducks_posters_1205_NghiaNT20_000096.txt (15 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000101.json -> epicducks_posters_1205_NghiaNT20_000101.txt (0 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000102.json -> epicducks_posters_1205_NghiaNT20_000102.txt (5 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000111.json -> epicducks_posters_1205_NghiaNT20_000111.txt (15 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000112.json -> epicducks_posters_1205_NghiaNT20_000112.txt (16 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000113.json -> epicducks_posters_1205_NghiaNT20_000113.txt (14 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000114.json -> epicducks_posters_1205_NghiaNT20_000114.txt (13 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000115.json -> epicducks_posters_1205_NghiaNT20_000115.txt (12 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000126.json -> epicducks_posters_1205_NghiaNT20_000126.txt (5 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000127.json -> epicducks_posters_1205_NghiaNT20_000127.txt (8 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000128.json -> epicducks_posters_1205_NghiaNT20_000128.txt (4 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000133.json -> epicducks_posters_1205_NghiaNT20_000133.txt (4 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000134.json -> epicducks_posters_1205_NghiaNT20_000134.txt (18 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000135.json -> epicducks_posters_1205_NghiaNT20_000135.txt (20 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000140.json -> epicducks_posters_1205_NghiaNT20_000140.txt (12 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000141.json -> epicducks_posters_1205_NghiaNT20_000141.txt (11 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000142.json -> epicducks_posters_1205_NghiaNT20_000142.txt (1 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000143.json -> epicducks_posters_1205_NghiaNT20_000143.txt (1 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000144.json -> epicducks_posters_1205_NghiaNT20_000144.txt (4 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000145.json -> epicducks_posters_1205_NghiaNT20_000145.txt (5 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000146.json -> epicducks_posters_1205_NghiaNT20_000146.txt (4 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000148.json -> epicducks_posters_1205_NghiaNT20_000148.txt (16 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000149.json -> epicducks_posters_1205_NghiaNT20_000149.txt (16 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000150.json -> epicducks_posters_1205_NghiaNT20_000150.txt (15 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000151.json -> epicducks_posters_1205_NghiaNT20_000151.txt (14 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000152.json -> epicducks_posters_1205_NghiaNT20_000152.txt (13 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000153.json -> epicducks_posters_1205_NghiaNT20_000153.txt (3 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000154.json -> epicducks_posters_1205_NghiaNT20_000154.txt (3 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000155.json -> epicducks_posters_1205_NghiaNT20_000155.txt (1 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000156.json -> epicducks_posters_1205_NghiaNT20_000156.txt (5 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000157.json -> epicducks_posters_1205_NghiaNT20_000157.txt (2 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000158.json -> epicducks_posters_1205_NghiaNT20_000158.txt (1 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000159.json -> epicducks_posters_1205_NghiaNT20_000159.txt (13 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000160.json -> epicducks_posters_1205_NghiaNT20_000160.txt (9 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000161.json -> epicducks_posters_1205_NghiaNT20_000161.txt (12 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000162.json -> epicducks_posters_1205_NghiaNT20_000162.txt (10 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000163.json -> epicducks_posters_1205_NghiaNT20_000163.txt (10 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000164.json -> epicducks_posters_1205_NghiaNT20_000164.txt (11 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000165.json -> epicducks_posters_1205_NghiaNT20_000165.txt (10 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000166.json -> epicducks_posters_1205_NghiaNT20_000166.txt (11 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000178.json -> epicducks_posters_1205_NghiaNT20_000178.txt (11 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000179.json -> epicducks_posters_1205_NghiaNT20_000179.txt (3 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000180.json -> epicducks_posters_1205_NghiaNT20_000180.txt (2 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000181.json -> epicducks_posters_1205_NghiaNT20_000181.txt (3 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000190.json -> epicducks_posters_1205_NghiaNT20_000190.txt (10 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000193.json -> epicducks_posters_1205_NghiaNT20_000193.txt (7 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000201.json -> epicducks_posters_1205_NghiaNT20_000201.txt (2 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000206.json -> epicducks_posters_1205_NghiaNT20_000206.txt (15 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000207.json -> epicducks_posters_1205_NghiaNT20_000207.txt (13 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000216.json -> epicducks_posters_1205_NghiaNT20_000216.txt (11 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000217.json -> epicducks_posters_1205_NghiaNT20_000217.txt (12 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000221.json -> epicducks_posters_1205_NghiaNT20_000221.txt (6 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_000222.json -> epicducks_posters_1205_NghiaNT20_000222.txt (11 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001779.json -> epicducks_posters_1205_NghiaNT20_001779.txt (13 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001780.json -> epicducks_posters_1205_NghiaNT20_001780.txt (10 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001781.json -> epicducks_posters_1205_NghiaNT20_001781.txt (8 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001782.json -> epicducks_posters_1205_NghiaNT20_001782.txt (12 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001783.json -> epicducks_posters_1205_NghiaNT20_001783.txt (13 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001784.json -> epicducks_posters_1205_NghiaNT20_001784.txt (13 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001785.json -> epicducks_posters_1205_NghiaNT20_001785.txt (12 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001786.json -> epicducks_posters_1205_NghiaNT20_001786.txt (13 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001787.json -> epicducks_posters_1205_NghiaNT20_001787.txt (2 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001788.json -> epicducks_posters_1205_NghiaNT20_001788.txt (2 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001791.json -> epicducks_posters_1205_NghiaNT20_001791.txt (2 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001792.json -> epicducks_posters_1205_NghiaNT20_001792.txt (3 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001793.json -> epicducks_posters_1205_NghiaNT20_001793.txt (2 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001794.json -> epicducks_posters_1205_NghiaNT20_001794.txt (5 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001795.json -> epicducks_posters_1205_NghiaNT20_001795.txt (13 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001796.json -> epicducks_posters_1205_NghiaNT20_001796.txt (10 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001797.json -> epicducks_posters_1205_NghiaNT20_001797.txt (14 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001798.json -> epicducks_posters_1205_NghiaNT20_001798.txt (11 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001799.json -> epicducks_posters_1205_NghiaNT20_001799.txt (5 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001800.json -> epicducks_posters_1205_NghiaNT20_001800.txt (6 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001801.json -> epicducks_posters_1205_NghiaNT20_001801.txt (7 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001802.json -> epicducks_posters_1205_NghiaNT20_001802.txt (5 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001803.json -> epicducks_posters_1205_NghiaNT20_001803.txt (10 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001804.json -> epicducks_posters_1205_NghiaNT20_001804.txt (10 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001805.json -> epicducks_posters_1205_NghiaNT20_001805.txt (11 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001806.json -> epicducks_posters_1205_NghiaNT20_001806.txt (10 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001807.json -> epicducks_posters_1205_NghiaNT20_001807.txt (12 instance(s))
# [OK] Processed: epicducks_posters_1205_NghiaNT20_001808.json -> epicducks_posters_1205_NghiaNT20_001808.txt (0 instance(s))
# ...
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000465.json -> This_Is_Streetball_1405_khaihoan2003_000465.txt (2 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000466.json -> This_Is_Streetball_1405_khaihoan2003_000466.txt (2 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000472.json -> This_Is_Streetball_1405_khaihoan2003_000472.txt (5 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000684.json -> This_Is_Streetball_1405_khaihoan2003_000684.txt (6 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000685.json -> This_Is_Streetball_1405_khaihoan2003_000685.txt (4 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000686.json -> This_Is_Streetball_1405_khaihoan2003_000686.txt (6 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000688.json -> This_Is_Streetball_1405_khaihoan2003_000688.txt (6 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000691.json -> This_Is_Streetball_1405_khaihoan2003_000691.txt (5 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000697.json -> This_Is_Streetball_1405_khaihoan2003_000697.txt (8 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000868.json -> This_Is_Streetball_1405_khaihoan2003_000868.txt (8 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000870.json -> This_Is_Streetball_1405_khaihoan2003_000870.txt (17 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000871.json -> This_Is_Streetball_1405_khaihoan2003_000871.txt (13 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000875.json -> This_Is_Streetball_1405_khaihoan2003_000875.txt (14 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000879.json -> This_Is_Streetball_1405_khaihoan2003_000879.txt (13 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000884.json -> This_Is_Streetball_1405_khaihoan2003_000884.txt (13 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000890.json -> This_Is_Streetball_1405_khaihoan2003_000890.txt (14 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000902.json -> This_Is_Streetball_1405_khaihoan2003_000902.txt (3 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000905.json -> This_Is_Streetball_1405_khaihoan2003_000905.txt (3 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000914.json -> This_Is_Streetball_1405_khaihoan2003_000914.txt (7 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000915.json -> This_Is_Streetball_1405_khaihoan2003_000915.txt (8 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000916.json -> This_Is_Streetball_1405_khaihoan2003_000916.txt (7 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000949.json -> This_Is_Streetball_1405_khaihoan2003_000949.txt (13 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000965.json -> This_Is_Streetball_1405_khaihoan2003_000965.txt (12 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000968.json -> This_Is_Streetball_1405_khaihoan2003_000968.txt (12 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000971.json -> This_Is_Streetball_1405_khaihoan2003_000971.txt (10 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000976.json -> This_Is_Streetball_1405_khaihoan2003_000976.txt (13 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000980.json -> This_Is_Streetball_1405_khaihoan2003_000980.txt (15 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000983.json -> This_Is_Streetball_1405_khaihoan2003_000983.txt (14 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000984.json -> This_Is_Streetball_1405_khaihoan2003_000984.txt (7 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000987.json -> This_Is_Streetball_1405_khaihoan2003_000987.txt (7 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000992.json -> This_Is_Streetball_1405_khaihoan2003_000992.txt (6 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000996.json -> This_Is_Streetball_1405_khaihoan2003_000996.txt (15 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_000997.json -> This_Is_Streetball_1405_khaihoan2003_000997.txt (6 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001020.json -> This_Is_Streetball_1405_khaihoan2003_001020.txt (11 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001036.json -> This_Is_Streetball_1405_khaihoan2003_001036.txt (3 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001039.json -> This_Is_Streetball_1405_khaihoan2003_001039.txt (8 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001040.json -> This_Is_Streetball_1405_khaihoan2003_001040.txt (4 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001060.json -> This_Is_Streetball_1405_khaihoan2003_001060.txt (17 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001076.json -> This_Is_Streetball_1405_khaihoan2003_001076.txt (4 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001087.json -> This_Is_Streetball_1405_khaihoan2003_001087.txt (3 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001111.json -> This_Is_Streetball_1405_khaihoan2003_001111.txt (6 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001112.json -> This_Is_Streetball_1405_khaihoan2003_001112.txt (6 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001113.json -> This_Is_Streetball_1405_khaihoan2003_001113.txt (6 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001114.json -> This_Is_Streetball_1405_khaihoan2003_001114.txt (10 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001115.json -> This_Is_Streetball_1405_khaihoan2003_001115.txt (11 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001116.json -> This_Is_Streetball_1405_khaihoan2003_001116.txt (13 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001117.json -> This_Is_Streetball_1405_khaihoan2003_001117.txt (12 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001122.json -> This_Is_Streetball_1405_khaihoan2003_001122.txt (11 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001123.json -> This_Is_Streetball_1405_khaihoan2003_001123.txt (14 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001140.json -> This_Is_Streetball_1405_khaihoan2003_001140.txt (9 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001141.json -> This_Is_Streetball_1405_khaihoan2003_001141.txt (9 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001410.json -> This_Is_Streetball_1405_khaihoan2003_001410.txt (11 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001411.json -> This_Is_Streetball_1405_khaihoan2003_001411.txt (13 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001412.json -> This_Is_Streetball_1405_khaihoan2003_001412.txt (12 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001413.json -> This_Is_Streetball_1405_khaihoan2003_001413.txt (11 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001414.json -> This_Is_Streetball_1405_khaihoan2003_001414.txt (14 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001415.json -> This_Is_Streetball_1405_khaihoan2003_001415.txt (13 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001416.json -> This_Is_Streetball_1405_khaihoan2003_001416.txt (16 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001422.json -> This_Is_Streetball_1405_khaihoan2003_001422.txt (13 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001424.json -> This_Is_Streetball_1405_khaihoan2003_001424.txt (4 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001425.json -> This_Is_Streetball_1405_khaihoan2003_001425.txt (5 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001426.json -> This_Is_Streetball_1405_khaihoan2003_001426.txt (4 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001428.json -> This_Is_Streetball_1405_khaihoan2003_001428.txt (5 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001441.json -> This_Is_Streetball_1405_khaihoan2003_001441.txt (2 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001442.json -> This_Is_Streetball_1405_khaihoan2003_001442.txt (2 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001445.json -> This_Is_Streetball_1405_khaihoan2003_001445.txt (6 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001446.json -> This_Is_Streetball_1405_khaihoan2003_001446.txt (7 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001447.json -> This_Is_Streetball_1405_khaihoan2003_001447.txt (7 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001450.json -> This_Is_Streetball_1405_khaihoan2003_001450.txt (2 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001451.json -> This_Is_Streetball_1405_khaihoan2003_001451.txt (2 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001877.json -> This_Is_Streetball_1405_khaihoan2003_001877.txt (11 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001880.json -> This_Is_Streetball_1405_khaihoan2003_001880.txt (11 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001883.json -> This_Is_Streetball_1405_khaihoan2003_001883.txt (11 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001887.json -> This_Is_Streetball_1405_khaihoan2003_001887.txt (11 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001890.json -> This_Is_Streetball_1405_khaihoan2003_001890.txt (11 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001895.json -> This_Is_Streetball_1405_khaihoan2003_001895.txt (10 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001906.json -> This_Is_Streetball_1405_khaihoan2003_001906.txt (3 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001907.json -> This_Is_Streetball_1405_khaihoan2003_001907.txt (4 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001908.json -> This_Is_Streetball_1405_khaihoan2003_001908.txt (4 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001912.json -> This_Is_Streetball_1405_khaihoan2003_001912.txt (5 instance(s))
# [OK] Processed: This_Is_Streetball_1405_khaihoan2003_001917.json -> This_Is_Streetball_1405_khaihoan2003_001917.txt (8 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000468.json -> What_A_Move_1705_khaihoan2003_000468.txt (14 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000471.json -> What_A_Move_1705_khaihoan2003_000471.txt (13 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000473.json -> What_A_Move_1705_khaihoan2003_000473.txt (14 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000476.json -> What_A_Move_1705_khaihoan2003_000476.txt (3 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000479.json -> What_A_Move_1705_khaihoan2003_000479.txt (4 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000480.json -> What_A_Move_1705_khaihoan2003_000480.txt (12 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000546.json -> What_A_Move_1705_khaihoan2003_000546.txt (11 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000549.json -> What_A_Move_1705_khaihoan2003_000549.txt (12 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000550.json -> What_A_Move_1705_khaihoan2003_000550.txt (4 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000554.json -> What_A_Move_1705_khaihoan2003_000554.txt (6 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000555.json -> What_A_Move_1705_khaihoan2003_000555.txt (7 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000614.json -> What_A_Move_1705_khaihoan2003_000614.txt (14 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000617.json -> What_A_Move_1705_khaihoan2003_000617.txt (12 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000618.json -> What_A_Move_1705_khaihoan2003_000618.txt (13 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000619.json -> What_A_Move_1705_khaihoan2003_000619.txt (13 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000648.json -> What_A_Move_1705_khaihoan2003_000648.txt (8 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000650.json -> What_A_Move_1705_khaihoan2003_000650.txt (7 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000652.json -> What_A_Move_1705_khaihoan2003_000652.txt (13 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000663.json -> What_A_Move_1705_khaihoan2003_000663.txt (7 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000665.json -> What_A_Move_1705_khaihoan2003_000665.txt (11 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000668.json -> What_A_Move_1705_khaihoan2003_000668.txt (15 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000678.json -> What_A_Move_1705_khaihoan2003_000678.txt (17 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000680.json -> What_A_Move_1705_khaihoan2003_000680.txt (15 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000681.json -> What_A_Move_1705_khaihoan2003_000681.txt (15 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000682.json -> What_A_Move_1705_khaihoan2003_000682.txt (15 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000684.json -> What_A_Move_1705_khaihoan2003_000684.txt (15 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000685.json -> What_A_Move_1705_khaihoan2003_000685.txt (14 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000686.json -> What_A_Move_1705_khaihoan2003_000686.txt (15 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000693.json -> What_A_Move_1705_khaihoan2003_000693.txt (12 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000695.json -> What_A_Move_1705_khaihoan2003_000695.txt (11 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000696.json -> What_A_Move_1705_khaihoan2003_000696.txt (12 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000697.json -> What_A_Move_1705_khaihoan2003_000697.txt (12 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000699.json -> What_A_Move_1705_khaihoan2003_000699.txt (12 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000700.json -> What_A_Move_1705_khaihoan2003_000700.txt (12 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000703.json -> What_A_Move_1705_khaihoan2003_000703.txt (1 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000705.json -> What_A_Move_1705_khaihoan2003_000705.txt (1 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000706.json -> What_A_Move_1705_khaihoan2003_000706.txt (1 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000708.json -> What_A_Move_1705_khaihoan2003_000708.txt (2 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000749.json -> What_A_Move_1705_khaihoan2003_000749.txt (11 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000751.json -> What_A_Move_1705_khaihoan2003_000751.txt (9 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000753.json -> What_A_Move_1705_khaihoan2003_000753.txt (9 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000754.json -> What_A_Move_1705_khaihoan2003_000754.txt (11 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000758.json -> What_A_Move_1705_khaihoan2003_000758.txt (6 instance(s))
# [OK] Processed: What_A_Move_1705_khaihoan2003_000759.json -> What_A_Move_1705_khaihoan2003_000759.txt (17 instance(s))
# Conversion finished. Files processed: 2041

# %% [markdown]
# ## Reformat all image to jpg:

# %%
from PIL import Image, UnidentifiedImageError
import os

"""
Script: png_to_jpg_inplace.py

Purpose:
    - Convert all PNG images in a folder to JPEG format.
    - If the PNG has an alpha channel (transparency), composite it over a solid
      background color (default: white) before saving as JPEG.
    - Optionally delete the original PNG after successful conversion.

Inputs:
    - image_folder: Directory containing the source .png files.

Outputs:
    - .jpg files with the same stem name as the original .png files.

Notes:
    - JPEG does not support transparency; transparent regions are filled with `bg_color`.
    - By default, the original .png is removed after conversion (configurable).
"""

# === CONFIGURATION ===
image_folder   = "data_json"          # Directory containing images
bg_color       = (255, 255, 255)      # Background color for PNGs with alpha (RGB)
jpeg_quality   = 92                   # JPEG quality (1–95 typical)
delete_source  = True                 # Remove original .png after conversion

# === CONVERT ALL PNG FILES IN FOLDER ===
for file in os.listdir(image_folder):
    if file.lower().endswith(".png"):
        src_path = os.path.join(image_folder, file)
        dst_name = os.path.splitext(file)[0] + ".jpg"
        dst_path = os.path.join(image_folder, dst_name)

        try:
            with Image.open(src_path) as img:
                # Handle alpha if present
                if img.mode in ("RGBA", "LA") or ("transparency" in img.info):
                    # Convert to RGBA to ensure alpha is available
                    rgba = img.convert("RGBA")
                    # Create background and composite
                    background = Image.new("RGB", rgba.size, bg_color)
                    background.paste(rgba, mask=rgba.split()[-1])  # last channel = alpha
                    out = background
                else:
                    # Ensure 3-channel RGB
                    out = img.convert("RGB")

                # Save JPEG with chosen quality; use optimize/progressive for smaller files
                out.save(dst_path, "JPEG", quality=jpeg_quality, optimize=True, progressive=True)

            # Optionally remove original PNG
            if delete_source:
                os.remove(src_path)

            print(f"[OK] Converted {file} -> {dst_name}")

        except UnidentifiedImageError:
            print(f"[WARN] Skipped (unreadable image): {file}")
        except Exception as e:
            print(f"[ERROR] Failed to convert {file}: {e}")

print("PNG to JPEG conversion completed.")
# Out:
# PNG to JPEG conversion completed.

# %% [markdown]
# ## Recheck missing data in TXT format

# %%
"""
Script: verify_image_label_pairs.py

Purpose:
    - Verify 1:1 pairing between image files and YOLO/segmentation label files (.txt)
      located in the same directory.
    - Report images that lack a matching .txt file and label files that lack a matching image.

Inputs:
    - folder_path: Directory containing both images and .txt label files.

Outputs:
    - Console report listing:
        * Images without label files
        * Label files without matching images
        * Totals and final status

Notes:
    - Pairing is determined by filename stem (e.g., "foo.jpg" <-> "foo.txt").
    - Matching is case-insensitive on file extensions.
"""

# === CONFIGURATION ===
folder_path = "data_txt"  # Directory containing images and .txt labels
image_exts = (".jpg", ".jpeg", ".png")  # Recognized image extensions (lowercased)

# === COLLECT BASENAMES AND EXTENSIONS ===
image_bases: dict[str, str] = {}  # base -> image extension (e.g., ".jpg")
label_bases: dict[str, str] = {}  # base -> ".txt"

for file in os.listdir(folder_path):
    base, ext = os.path.splitext(file)
    ext = ext.lower()

    if ext in image_exts:
        image_bases[base] = ext
    elif ext == ".txt":
        label_bases[base] = ext

image_names = set(image_bases.keys())
label_names = set(label_bases.keys())

# === FIND MISMATCHES ===
images_missing_label = image_names - label_names
labels_missing_image = label_names - image_names

print("=== Validation Report ===")

if images_missing_label:
    print("Images without label files:")
    for name in sorted(images_missing_label):
        print(f" - {name}{image_bases.get(name, '')}")

if labels_missing_image:
    print("\nLabel files without matching images:")
    for name in sorted(labels_missing_image):
        print(f" - {name}{label_bases.get(name, '')}")

# === TOTALS ===
total_images = len(image_names)
total_labels = len(label_names)
total_files = total_images + total_labels

print(f"\nTotals: {total_files} files (images: {total_images}, labels: {total_labels})")

# === FINAL STATUS ===
if not images_missing_label and not labels_missing_image:
    print("All images and label files are correctly paired.")
else:
    print("Mismatch detected: At least one image or label file is missing its pair.")
# Out:
# === Validation Report ===
#
# Totals: 4082 files (images: 2041, labels: 2041)
# All images and label files are correctly paired.

# %% [markdown]
# ## Split Original dataset to train/val.

# %%
import os
import json
import shutil
from collections import defaultdict
from sklearn.model_selection import train_test_split

"""
Script: split_dataset_by_primary_class.py

Purpose:
    - Split a dataset into Train and Val subsets based on the primary (first) class_id
      found in each YOLO Segmentation label file (.txt).
    - Perform a per-class split using a fixed validation ratio.
    - Copy paired image/label files into the output structure:
          dataset/
            images/
              train/
              val/
            labels/
              train/
              val/

Inputs:
    - image_dir:  Directory containing source images (.jpg, .png).
    - label_dir:  Directory containing YOLO segmentation labels (.txt).
    - output_dir: Destination root directory for the split dataset.
    - val_ratio:  Validation split ratio (e.g., 0.2 for 80/20).

Outputs:
    - Files copied into {output_dir}/images/{train|val} and {output_dir}/labels/{train|val}.

Notes:
    - The "primary class" is taken as the first class_id token on the first non-empty line
      of each label file. If a file contains instances of multiple classes, this script
      still assigns the file to a single class by that first token.
    - A class bucket with < 2 files cannot be split; those files are put into Train.
"""

# === CONFIGURATION ===
image_dir = "data_txt"     # Directory containing source images (.jpg, .png)
label_dir = "data_txt"     # Directory containing YOLO segmentation label files (.txt)
output_dir = "dataset"     # Output root directory
val_ratio = 0.2            # Validation split ratio

# === CREATE OUTPUT FOLDERS ===
for split in ["train", "val"]:
    os.makedirs(os.path.join(output_dir, "images", split), exist_ok=True)
    os.makedirs(os.path.join(output_dir, "labels", split), exist_ok=True)

# === MAP EACH LABEL FILE TO ITS PRIMARY CLASS_ID ===
label_to_class = {}
for fname in os.listdir(label_dir):
    if fname.endswith(".txt"):
        path = os.path.join(label_dir, fname)
        with open(path, "r", encoding="utf-8") as f:
            lines = f.readlines()
            classes = [line.strip().split()[0] for line in lines if line.strip()]
            main_class = classes[0] if classes else None
            if main_class is not None:
                base_name = os.path.splitext(fname)[0]
                label_to_class[base_name] = int(main_class)

# === GROUP FILES BY CLASS_ID ===
class_to_files = defaultdict(list)
for base_name, class_id in label_to_class.items():
    class_to_files[class_id].append(base_name)

# === PER-CLASS SPLIT (OR FALL BACK TO TRAIN IF NOT ENOUGH FILES) ===
train_set = set()
val_set = set()

for class_id, files in class_to_files.items():
    if len(files) < 2:
        # Not enough files to split -> assign all to Train
        train_set.update(files)
        print(f"Class {class_id} has {len(files)} file(s) -> assigning to Train.")
    else:
        train_files, val_files = train_test_split(
            files, test_size=val_ratio, random_state=42, shuffle=True
        )
        train_set.update(train_files)
        val_set.update(val_files)

# === FILE COPY HELPER ===
def copy_file(base_name: str, split: str) -> None:
    """
    Copy the image (by trying common extensions) and its .txt label into the split folder.
    """
    # Copy image
    found = False
    for ext in [".jpg", ".png"]:
        img_path = os.path.join(image_dir, base_name + ext)
        if os.path.exists(img_path):
            shutil.copy2(img_path, os.path.join(output_dir, "images", split, base_name + ext))
            found = True
            break
    if not found:
        print(f"[WARN] Image not found for base name: {base_name}")

    # Copy label
    label_src = os.path.join(label_dir, base_name + ".txt")
    if os.path.exists(label_src):
        shutil.copy2(label_src, os.path.join(output_dir, "labels", split, base_name + ".txt"))
    else:
        print(f"[WARN] Label file not found: {base_name}.txt")

# === EXECUTE COPY ===
for b in train_set:
    copy_file(b, "train")
for b in val_set:
    copy_file(b, "val")

# === SUMMARY ===
print("\nTrain/Val split by primary class completed.")
print(f"Train set size: {len(train_set)} file(s)")
print(f"Val set size  : {len(val_set)} file(s)")
# Out:
# Class 7 has 1 file(s) -> assigning to Train.
#
# Train/Val split by primary class completed.
# Train set size: 1618 file(s)
# Val set size  : 411 file(s)
