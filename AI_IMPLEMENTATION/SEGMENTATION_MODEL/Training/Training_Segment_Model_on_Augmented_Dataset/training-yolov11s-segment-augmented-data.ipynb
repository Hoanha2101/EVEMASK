# %%
# !pip install ultralytics
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7e9f62232110>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/ultralytics/

# %%
from ultralytics import YOLO
def main():
    model = YOLO('/kaggle/input/load-model/yolo11s-seg.pt')  
    results = model.train(data='/kaggle/input/file-yyaml-new/dataset.yaml',imgsz=640,epochs=30,
                          optimizer="AdamW", cache=True, batch=24, device=0, patience=1000,
                          lr0 = 0.01,
                          # fliplr = 0, crop_fraction = 0 ,mixup =0, copy_paste=1,perspective=0,
                          # mosaic=0,shear=0,degrees=0,
                          # hsv_h=0.15, hsv_s=0.7, hsv_v = 0.5, translate = 0)
                         )
if __name__ == '__main__':
    main()

# %%
# !zip -r /kaggle/working/runs_yolo.zip /kaggle/working/runs/segment/train2
